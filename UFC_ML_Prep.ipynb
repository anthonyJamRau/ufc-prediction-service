# %%
import pandas as pd

# %%
fight = pd.read_csv('scraped_files/ufc_fight_data.csv', encoding='ISO-8859-1')

# %%
fight_stat = pd.read_csv('scraped_files/ufc_fight_stat_data.csv', encoding='ISO-8859-1')

# %%
event = pd.read_csv('scraped_files/ufc_event_data.csv', encoding='ISO-8859-1')

# %%
fighter = pd.read_csv('scraped_files/ufc_fighter_data.csv', encoding='ISO-8859-1')

# %%
upcoming = pd.read_csv('scraped_files/upcoming_events.csv', encoding='ISO-8859-1')

# %%
tML = fight_stat.merge(fight,on='fight_id',how='inner')

# %%
tML.merge(event,on='event_id',how='inner')
# Out:
#       fight_stat_id  fight_id         fighter_id  knockdowns  \
# 0             14611      7331       Leon Edwards         0.0
# 1             14610      7331    Colby Covington         0.0
# 2             14609      7330  Alexandre Pantoja         0.0
# 3             14608      7330     Brandon Royval         0.0
# 4             14607      7329  Shavkat Rakhmonov         0.0
# ...             ...       ...                ...         ...
# 1342          13269      6660  Victor Altamirano         1.0
# 1343          13268      6659        Marlon Vera         3.0
# 1344          13267      6659      Dominick Cruz         0.0
# 1345          13266      6658      Nate Landwehr         0.0
# 1346          13265      6658        David Onama         1.0
#
#       total_strikes_att  total_strikes_succ  sig_strikes_att  \
# 0                 116.0                65.0            108.0
# 1                 194.0               109.0            126.0
# ...

# %%
tML['event_id']
# Out:
# 0        674.0
# 1        674.0
# 2        673.0
# 3        673.0
# 4        672.0
#          ...
# 14606      NaN
# 14607      NaN
# 14608      NaN
# 14609      NaN
# 14610      NaN
# Name: event_id, Length: 14611, dtype: float64

# %%
fight.head(30)
# Out:
#     fight_id  event_id         referee  f_1   f_2  winner num_rounds  \
# 0       7331     674.0       Herb Dean  NaN   NaN     NaN          5
# 1       7330     673.0    Marc Goddard  NaN   NaN     NaN          5
# 2       7329     672.0    Jason Herzog  NaN   NaN     NaN          3
# 3       7328     671.0      Mark Smith  NaN   NaN     NaN          3
# 4       7327     670.0       Herb Dean  NaN   NaN     NaN          3
# 5       7326     669.0   Chris Tognoni  NaN   NaN     NaN          3
# 6       7325     668.0    Jason Herzog  NaN   NaN     NaN          3
# 7       7324     667.0    Marc Goddard  NaN   NaN     NaN          3
# 8       7323     666.0      Mark Smith  NaN   NaN     NaN          3
# 9       7322     665.0   Chris Tognoni  NaN   NaN     NaN          3
# 10      7321     664.0    Jason Herzog  NaN   NaN     NaN          3
# 11      7320     663.0      Mark Smith  NaN   NaN     NaN          3
# 12      7319     662.0       Herb Dean  NaN   NaN     NaN          5
# ...

# %%
event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       674 non-null    int64
#  1   event_name     674 non-null    object
#  2   event_date     674 non-null    object
#  3   event_city     674 non-null    object
#  4   event_state    625 non-null    object
#  5   event_country  674 non-null    object
#  6   event_url      674 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 37.0+ KB

# %%
upcoming.head()
# Out:
#                                event_name              date         fighter_1  \
# 0  UFC Fight Night: Ankalaev vs. Walker 2  January 13, 2024  Magomed Ankalaev
# 1  UFC Fight Night: Ankalaev vs. Walker 2  January 13, 2024   Matheus Nicolau
# 2  UFC Fight Night: Ankalaev vs. Walker 2  January 13, 2024        Jim Miller
# 3  UFC Fight Night: Ankalaev vs. Walker 2  January 13, 2024       Ricky Simon
# 4  UFC Fight Night: Ankalaev vs. Walker 2  January 13, 2024        Phil Hawes
#
#          fighter_2           division  \
# 0    Johnny Walker  Light Heavyweight
# 1       Manel Kape          Flyweight
# 2  Gabriel Benitez        Lightweight
# 3   Mario Bautista       Bantamweight
# 4  Brunno Ferreira       Middleweight
#
#                                            event_url
# 0  http://ufcstats.com/event-details/010986ee359f...
# 1  http://ufcstats.com/event-details/010986ee359f...
# 2  http://ufcstats.com/event-details/010986ee359f...
# ...
