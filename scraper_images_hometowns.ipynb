# %%
import requests
import bs4
import pandas as pd
import time
import logging

# %%
df_store = pd.DataFrame(columns = ['fighter_name','image_path','fighter_country_code','fighter_country'])

# %%
country_code_map = {
    "AL": "Albania",
    "AR": "Argentina",
    "AM": "Armenia",
    "AU": "Australia",
    "AT": "Austria",
    "AZ": "Azerbaijan",
    "BH": "Bahrain",
    "BE": "Belgium",
    "BO": "Bolivia",
    "BR": "Brazil",
    "BG": "Bulgaria",
    "CM": "Cameroon",
    "CA": "Canada",
    "CL": "Chile",
    "CN": "China",
    "CO": "Colombia",
    "CR": "Costa Rica",
    "HR": "Croatia",
    "CZ": "Czechia",
    "CD": "Democratic Republic of the Congo",
    "DK": "Denmark",
    "EC": "Ecuador",
    "EN": "England", 
    "FI": "Finland",
    "FR": "France",
    "GE": "Georgia",
    "DE": "Germany",
    "GR": "Greece",
    "GU": "Guam",
    "HK": "Hong Kong",
    "HU": "Hungary",
    "IS": "Iceland",
    "IN": "India",
    "ID": "Indonesia",
    "IE": "Ireland",
    "IT": "Italy",
    "JP": "Japan",
    "JO": "Jordan",
    "KZ": "Kazakhstan",
    "KG": "Kyrgyzstan",
    "LT": "Lithuania",
    "MX": "Mexico",
    "MD": "Moldova",
    "MN": "Mongolia",
    "MA": "Morocco",
    "NL": "Netherlands",
    "NZ": "New Zealand",
    "NO": "Norway",
    "PA": "Panama",
    "PY": "Paraguay",
    "PE": "Peru",
    "PH": "Philippines",
    "PL": "Poland",
    "PT": "Portugal",
    "RO": "Romania",
    "RU": "Russia",
    "SF": "Scotland", 
    "RS": "Serbia",
    "SG": "Singapore",
    "SK": "Slovakia",
    "ZA": "South Africa",
    "KR": "South Korea",
    "ES": "Spain",
    "SR": "Suriname",
    "SE": "Sweden",
    "CH": "Switzerland",
    "TW": "Taiwan",
    "TJ": "Tajikistan",
    "TH": "Thailand",
    "TR": "Türkiye",
    "UA": "Ukraine",
    "AE": "United Arab Emirates",
    "GB": "United Kingdom",  
    "US": "United States",
    "UY": "Uruguay",
    "UZ": "Uzbekistan",
    "VE": "Venezuela",
    "WL": "Wales"  
}

# %%
len(country_code_map)
# Out:
# 78

# %%
for country_code in country_code_map.keys():

    request_url = f"https://www.ufc.com/athletes/all?filters[0]=location:{country_code}"
    response = requests.get(request_url,verify=False)
    location_page_soup = bs4.BeautifulSoup(response.text)
    fighters = [fighter for fighter in location_page_soup.find_all('li', class_='l-flex__item') if fighter.find('div', class_='node node--type-athlete node--view-mode-all-athletes-result ds-1col clearfix')]

    for fighter in fighters:
        name_tag = fighter.find('span',class_='c-listing-athlete__name')
        name = name_tag.get_text(strip=True)
        image_tag = fighter.find('img',class_='image-style-teaser')
        image_url = image_tag['src'] if image_tag else 'NULL'
        df_store.loc[len(df_store.index)] = [name,image_url,country_code,country_code_map[country_code]]

    time.sleep(1)
# Out:
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
df_store.loc[0].to_dict()
# Out:
# {'fighter_name': 'Mostapha Al Turk',
#  'image_path': 'NULL',
#  'fighter_country_code': 'GB',
#  'fighter_country': 'United Kingdom'}

# %%
# row by row to slow requests
for index,row in df_store.iterrows():
    image_url = row['image_path']
    if image_url != 'NULL':
        response = requests.get(image_url, verify=False)
        if response.status_code == 200:
            with open(f"data/images/{row['fighter_name']}.png", 'wb') as f:
                f.write(response.content)
        else:
            logging.warning(f"{image_url} not accessed. Code {response.status_code}")
        time.sleep(1)
    else:
        continue
# Out:
# fighter_name                                                Mounir Lazzez
# image_path              https://ufc.com/images/styles/teaser/s3/2023-0...
# fighter_country_code                                                   AE
# fighter_country                                      United Arab Emirates
# Name: 246, dtype: object
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
