# %%
import requests
import bs4

# %%
request_url = "https://www.ufc.com/athletes/all?filters[0]=location:AT"
response = requests.get(request_url,verify=False)
# Out:
# c:\Users\RautaN01\Documents\project1\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ufc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
bs4.BeautifulSoup(response.text)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="The source for fighter bios, records, past fights, video highlights, and more." name="description"/>
# <meta content="ufc, athletes, champions" name="keywords"/>
# <link href="https://www.ufc.com/athletes/all" rel="canonical"/>
# <meta content="origin" name="referrer"/>
# <meta content="UFC Fighters, Bios, Event History, Pictures &amp; Video | UFC.com" name="title"/>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>
#   function initAnswers() {
#     ANSWERS.init({
#       apiKey: "850a88aeb3c29599ce2db46832aa229f",
#       experienceKey: "answers-en",
#       experienceVersion: "PRODUCTION",
#       locale: "en",
#       businessId: "3668711",
# ...
